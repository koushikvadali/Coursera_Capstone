# %% [markdown]
# <strong>Week-3 Assignment</strong>
#
# <strong>Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto</strong>

# %%
import pandas as pd

import numpy as np

# %%
path='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

# %%
d=pd.read_html(path,flavor='bs4',skiprows=2,header=None)

# %%
d
# Out:
# [     M2A      Not assigned                                         Unnamed: 2
#  0    M3A        North York                                          Parkwoods
#  1    M4A        North York                                   Victoria Village
#  2    M5A  Downtown Toronto                         Regent Park / Harbourfront
#  3    M6A        North York                  Lawrence Manor / Lawrence Heights
#  4    M7A  Downtown Toronto       Queen's Park / Ontario Provincial Government
#  5    M8A      Not assigned                                                NaN
#  6    M9A         Etobicoke                                   Islington Avenue
#  7    M1B       Scarborough                                    Malvern / Rouge
#  8    M2B      Not assigned                                                NaN
#  9    M3B        North York                                          Don Mills
#  10   M4B         East York                   Parkview Hill / Woodbine Gardens
# ...

# %%
type(d)
# Out:
# list

# %%
df=d[0]

df
# Out:
#      M2A      Not assigned                                         Unnamed: 2
# 0    M3A        North York                                          Parkwoods
# 1    M4A        North York                                   Victoria Village
# 2    M5A  Downtown Toronto                         Regent Park / Harbourfront
# 3    M6A        North York                  Lawrence Manor / Lawrence Heights
# 4    M7A  Downtown Toronto       Queen's Park / Ontario Provincial Government
# 5    M8A      Not assigned                                                NaN
# 6    M9A         Etobicoke                                   Islington Avenue
# 7    M1B       Scarborough                                    Malvern / Rouge
# 8    M2B      Not assigned                                                NaN
# 9    M3B        North York                                          Don Mills
# 10   M4B         East York                   Parkview Hill / Woodbine Gardens
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['M2A', 'Not assigned', 'Unnamed: 2'], dtype='object')

# %%
cols=['Postal code','Borough','Neighborhood']
df.columns=cols

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M8A      Not assigned
# 6           M9A         Etobicoke
# 7           M1B       Scarborough
# 8           M2B      Not assigned
# 9           M3B        North York
# 10          M4B         East York
# 11          M5B  Downtown Toronto
# 12          M6B        North York
# 13          M7B      Not assigned
# 14          M8B      Not assigned
# 15          M9B         Etobicoke
# 16          M1C       Scarborough
# 17          M2C      Not assigned
# 18          M3C        North York
# 19          M4C         East York
# 20          M5C  Downtown Toronto
# 21          M6C              York
# 22          M7C      Not assigned
# 23          M8C      Not assigned
# 24          M9C         Etobicoke
# 25          M1E       Scarborough
# ...

# %%
df.replace("Not assigned",np.nan,inplace=True)

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M8A               NaN
# 6           M9A         Etobicoke
# 7           M1B       Scarborough
# 8           M2B               NaN
# 9           M3B        North York
# 10          M4B         East York
# 11          M5B  Downtown Toronto
# 12          M6B        North York
# 13          M7B               NaN
# 14          M8B               NaN
# 15          M9B         Etobicoke
# 16          M1C       Scarborough
# 17          M2C               NaN
# 18          M3C        North York
# 19          M4C         East York
# 20          M5C  Downtown Toronto
# 21          M6C              York
# 22          M7C               NaN
# 23          M8C               NaN
# 24          M9C         Etobicoke
# 25          M1E       Scarborough
# ...

# %%
df.dropna(subset=["Borough"],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
df['Postal code'].value_counts() #check to see if there are any duplicate values.
# Out:
# M6M    1
# M2N    1
# M5L    1
# M2M    1
# M3B    1
# M1R    1
# M6E    1
# M5A    1
# M9B    1
# M6R    1
# M1G    1
# M2H    1
# M3A    1
# M4B    1
# M4C    1
# M6S    1
# M8Y    1
# M7R    1
# M5K    1
# M4T    1
# M5P    1
# M1K    1
# M7A    1
# M8X    1
# M4Y    1
# M5V    1
# M5N    1
# M4R    1
# M1X    1
# M6K    1
# M8Z    1
# M5X    1
# M2P    1
# M7Y    1
# M2K    1
# M8W    1
# M6H    1
# M4N    1
# M3H    1
# M4H    1
# M9M    1
# M1M    1
# M1N    1
# M4J    1
# M4M    1
# M2L    1
# M5C    1
# M3K    1
# M4G    1
# M5S    1
# M5G    1
# M6J    1
# M1L    1
# M3N    1
# M1T    1
# M9R    1
# M6N    1
# M4W    1
# M9C    1
# M6A    1
# M2R    1
# M4P    1
# M9L    1
# M5H    1
# M6P    1
# M9N    1
# M5B    1
# M5R    1
# M1J    1
# M1B    1
# M1C    1
# M4L    1
# M9W    1
# M9P    1
# M6C    1
# M1P    1
# M3L    1
# M5W    1
# M1E    1
# M2J    1
# M3M    1
# M4X    1
# M5E    1
# M1S    1
# M4A    1
# M6B    1
# M5T    1
# M1V    1
# M4V    1
# M9V    1
# ...

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
df['Neighborhood']=df['Neighborhood'].str.replace('/',',')

# %%
df
# Out:
#     Postal code           Borough  \
# 0           M3A        North York
# 1           M4A        North York
# 2           M5A  Downtown Toronto
# 3           M6A        North York
# 4           M7A  Downtown Toronto
# 5           M9A         Etobicoke
# 6           M1B       Scarborough
# 7           M3B        North York
# 8           M4B         East York
# 9           M5B  Downtown Toronto
# 10          M6B        North York
# 11          M9B         Etobicoke
# 12          M1C       Scarborough
# 13          M3C        North York
# 14          M4C         East York
# 15          M5C  Downtown Toronto
# 16          M6C              York
# 17          M9C         Etobicoke
# 18          M1E       Scarborough
# 19          M4E      East Toronto
# 20          M5E  Downtown Toronto
# 21          M6E              York
# 22          M1G       Scarborough
# 23          M4G         East York
# 24          M5G  Downtown Toronto
# 25          M6G  Downtown Toronto
# ...

# %%
df.shape
# Out:
# (103, 3)
